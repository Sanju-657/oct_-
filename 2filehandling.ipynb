# %%
file_name="mbox-short.txt"
file=open(file_name)
data=file.read()
for i in data:
    print(i)
# Out:
# F
# r
# o
# m
#
# s
# t
# e
# p
# h
# e
# n
# .
# m
# a
# r
# q
# u
# a
# r
# d
# @
# u
# c
# t
# .
# a
# c
# .
# z
# a
#
# S
# a
# t
#
# J
# a
# n
#
#
# 5
#
# 0
# 9
# :
# 1
# 4
# :
# 1
# 6
#
# 2
# 0
# 0
# 8
#
#
# R
# e
# t
# u
# r
# n
# -
# P
# a
# t
# h
# :
#
# <
# p
# o
# s
# t
# m
# a
# s
# t
# e
# r
# @
# c
# o
# l
# l
# a
# b
# .
# s
# a
# k
# a
# i
# p
# r
# o
# j
# e
# c
# t
# .
# o
# r
# g
# >
#
#
# R
# e
# c
# e
# i
# v
# e
# d
# :
#
# f
# r
# o
# m
#
# m
# u
# r
# d
# e
# r
#
# (
# m
# a
# i
# l
# .
# u
# m
# i
# c
# h
# .
# e
# d
# u
#
# [
# 1
# 4
# 1
# .
# 2
# 1
# 1
# .
# 1
# 4
# .
# 9
# 0
# ]
# )
#
#
#
#
# b
# y
#
# f
# r
# a
# n
# k
# e
# n
# s
# t
# e
# i
# n
# .
# m
# a
# i
# l
# .
# u
# m
# i
# c
# h
# .
# e
# d
# u
#
# (
# C
# y
# r
# u
# s
#
# v
# 2
# .
# 3
# .
# 8
# )
#
# w
# i
# t
# h
#
# L
# M
# T
# P
# A
# ;
#
#
#
#
# S
# a
# t
# ,
#
# 0
# 5
#
# J
# a
# n
#
# 2
# 0
# 0
# 8
#
# 0
# 9
# :
# 1
# 4
# :
# 1
# 6
#
# -
# 0
# 5
# 0
# 0
#
#
# X
# -
# S
# i
# e
# v
# e
# ...

# %%
file_name="mbox-short.txt"
file=open(file_name)
data=file.read()
with file_name as file:
    print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 file=open(file_name)
#       3 data=file.read()
# ----> 4 with file_name as file:
#       5     print(data)
#
# TypeError: 'str' object does not support the context manager protocol

# %%
**mode**
 - by default the mode is :"r" read mode
- if we wants to create file  and write any info then we need to change the mode

# %%
file_name="mbox-short.txt"
file=open(file_name)
for i in file:
    print(i)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# X-Sieve: CMU Sieve 2.3
#
# Received: from murder ([unix socket])
#
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 	Sat, 5 Jan 2008 09:14:15 -0500
#
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 	 5 Jan 2008 09:14:10 -0500
#
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
file_name="movie.txt"
file=open(file_name,mode='r')
data=file.read()

# %%
file_name="movie.txt"
file=open(file_name,mode='a')
file.write('i need to be consistent')
# Out:
# 23

# %%
len('i need to be consistent')
# Out:
# 23

# %%
file_name="movie2.txt"
with open(file_name,mode='w') as file:
    file.write('consistency i the key for success')

# %%
file_name="movie2.txt"
with open(file_name,mode='a') as file:
    file.write('ur life is joke')

# %% [markdown]
# - take the file name
# - open the file,fix your mode
# - if mode is **r** then file.read()
# - if mode is **w** then file.write()

# %% [markdown]
# **case-1**
# - i don't want write a new file at python location
# - i want to create a new folder at python location
# - in that folder i want to save my new file

# %%
#create a folder first
#folder name=files
#then provide the full directory
#if you write the file without **with** keyword
#first time we will see 0kb
#if that occurs run again
file_name="path"
file=open(file_name,mode='w')
file.write('i need to be consistent')
# Out:
# 23

# %% [markdown]
# - we created a folder
# - we provided the full path
# - we are writing the file
# - the first two steps should happen automatically

# %% [markdown]
# - step-1: we created a folder
#   - for this we need a package called **os**
#     - in that os we need a method **makedirs**
# #make directories
# - step-2:provide the full path
#   -A.Till python location path
#      - we need a package name:"os"
#         - method name:**getcwd**
#
#   -B.Your new folder name
#       -we already given
#     -when you continues this it becomes new folder location
#       - **os.path.join**

# %%
import os
new_folder_name='files1'
try:
    os.makedirs(new_folder_name)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'files1'

# %%
import os
cwd=os.getcwd()
print(cwd)
#########################################
new_folder_name='fest1'
new_dir=os.path.join(cwd,new_folder_name)#A+B
print(new_dir)
#########################################
file_name='movie2.txt'
new_location=os.path.join(new_dir,file_name)
print(new_location)
#########################################
file=open(new_location,mode='w')
file.write('movie one time watch')
# Out:
# C:\Users\saite
# C:\Users\saite\fest1
# C:\Users\saite\fest1\movie2.txt
# 20
