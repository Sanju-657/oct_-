# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import pandas as pd
visa_df=pd.read_csv(r"C:\Users\saite\Documents\DATA FILES FOR PROJECTS\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['education_of_employee'].isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: education_of_employee, Length: 25480, dtype: bool

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.take([3,5,8],axis=1)
# Out:
#       has_job_experience  no_of_employees  prevailing_wage
# 0                      N            14513         592.2029
# 1                      Y             2412       83425.6500
# 2                      N            44444      122996.8600
# 3                      N               98       83434.0300
# 4                      Y             1082      149907.3900
# ...                  ...              ...              ...
# 25475                  Y             2601       77092.5700
# 25476                  Y             3274      279174.7900
# 25477                  Y             1121      146298.8500
# 25478                  Y             1918       86154.7700
# 25479                  Y             3195       70876.9100
#
# [25480 rows x 3 columns]

# %%
pd.read_csv(r"C:\Users\saite\Downloads\bank.csv",sep=';')
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %% [markdown]
# - type
# - len
# - shape
# - size
# - head
# - tail
# - isnull

# %% [markdown]
# **TYPE**

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **len**

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# **shape**

# %%
visa_df.shape
import numpy as np
np.shape(visa_df)# shape will gives the count of rows and columns in the dataframe
# Out:
# (25480, 12)

# %% [markdown]
# **Size**

# %%
visa_df.size # size is the function which gives the no of elements present in the dataframe includes missing values +zero+etc..
# Out:
# 305760

# %%
visa_df.shape[0]#rows accessed by 0 ie.e is shape[0] gives the total no of zeroes in the dataframe
# Out:
# 25480

# %%
visa_df.shape[1]#columns accessed by 1 i.e is shape[1] gives the no of columns in the dataframe
# Out:
# 12

# %% [markdown]
# **Head**

# %%
visa_df.head()# first five elements of the datafile is thrown as o/p
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
visa_df.tail()## last 5 elements in file will be thrown as o/p
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.isnull()# isnull() is one of functions used  for dataframes ,it gives True as output for a number False for NaN not a number
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.columns.index('no of employees')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 visa_df.columns.index('no of employees')
#
# AttributeError: 'Index' object has no attribute 'index'

# %%
list(visa_df.columns).index('no_of_employees')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 list(visa_df.columns).index('no_of_employees')
#
# ValueError: 'no_of_employees' is not in list

# %%
visa_df.dtypes#object:categorical
# series series
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# - dataframe has rows and columns
# - dataframe we can see column names
# - but series is given as two vertical values
# - there is no heading in series
# - series is represented as key:value pair

# %% [markdown]
# **Always learn how to display a dataframe using series**

# %%
dtypes=visa_df.dtypes
dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %% [markdown]
# **task-1: extract numerical and categorical columns separately**

# %%
for i,j in dtypes.items():
    if j!='object':
        print(i)# throws o/p as column's headings of numerical data
# Out:
# no_of_employees
# yr_of_estab
# prevailing_wage

# %%
for i,j in dtypes.items():
    if j=='int64':
        print(i)
# Out:
# no_of_employees
# yr_of_estab

# %%
for i,j in dtypes.items():
    if j=='float64':
        print(i)
# Out:
# prevailing_wage

# %%
for i,j in dtypes.items():
    if j=='int':
        print(i)

# %%
for i,j in dtypes.items():
    if j=='object':
        print(i)#throws o/p as column headings of objects(categorical data)
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# region_of_employment
# unit_of_wage
# full_time_position
# case_status

# %%
categorical=[i for i,j in dtypes.items() if j=='object']
categorical
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
numerical=[i for i,j in dtypes.items() if j!='object']
numerical
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# **select dtypes**

# %%
visa_df.select_dtypes(include='object')
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
visa_df.select_dtypes(exclude='object')
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# 0                14513         2007         592.2029
# 1                 2412         2002       83425.6500
# 2                44444         2008      122996.8600
# 3                   98         1897       83434.0300
# 4                 1082         2005      149907.3900
# ...                ...          ...              ...
# 25475             2601         2008       77092.5700
# 25476             3274         2006      279174.7900
# 25477             1121         1910      146298.8500
# 25478             1918         1887       86154.7700
# 25479             3195         1960       70876.9100
#
# [25480 rows x 3 columns]

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
dir(visa_df.select_dtypes)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__func__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__self__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# **Method-1**

# %%
dtypes=visa_df.dtypes
keys=visa_df.keys()
values=visa_df.values
df=pd.DataFrame(zip(keys,values),columns=['Column Name','Data Types'])
#print(df.to_csv(r"C:\Users\saite\Downloads\output.csv",index=True))
df.to_csv
# Out:
# <bound method NDFrame.to_csv of               Column Name                                         Data Types
# 0                 case_id  [EZYV01, Asia, High School, N, N, 14513, 2007,...
# 1               continent  [EZYV02, Asia, Master's, Y, N, 2412, 2002, Nor...
# 2   education_of_employee  [EZYV03, Asia, Bachelor's, N, Y, 44444, 2008, ...
# 3      has_job_experience  [EZYV04, Asia, Bachelor's, N, N, 98, 1897, Wes...
# 4   requires_job_training  [EZYV05, Africa, Master's, Y, N, 1082, 2005, S...
# 5         no_of_employees  [EZYV06, Asia, Master's, Y, N, 2339, 2012, Sou...
# 6             yr_of_estab  [EZYV07, Asia, Bachelor's, N, N, 4985, 1994, S...
# 7    region_of_employment  [EZYV08, North America, Bachelor's, Y, N, 3035...
# 8         prevailing_wage  [EZYV09, Asia, Bachelor's, N, N, 4810, 2012, M...
# 9            unit_of_wage  [EZYV10, Europe, Doctorate, Y, N, 2251, 1995, ...
# 10     full_time_position  [EZYV11, Asia, Master's, N, N, 2465, 2004, Mid...
# ...

# %%
visa_df.head()

# %%
df=pd.DataFrame(zip(categorical,numerical))
df
# Out:
#                        0                1
# 0                case_id  no_of_employees
# 1              continent      yr_of_estab
# 2  education_of_employee  prevailing_wage

# %% [markdown]
# **Method-2**

# %%
dtypes=visa_df.dtypes
pd.DataFrame(dtypes.items())
# Out:
#                         0        1
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %% [markdown]
# **Method-3**

# %%
dict(visa_df.dtypes)
#pd.DataFrame(dict1)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
val=dict(visa_df.dtypes)
pd.DataFrame(val,index=['A'])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# A  object    object                object             object
#
#   requires_job_training no_of_employees yr_of_estab region_of_employment  \
# A                object           int64       int64               object
#
#   prevailing_wage unit_of_wage full_time_position case_status
# A         float64       object             object      object

# %% [markdown]
# **isnull**

# %% [markdown]
# - is null means we are asking a question is there any null value available or not
# - when we ask a question to computer the answer either True oe False
# - True means yes ,we have a null value
# - False means no we do not have a null value

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# **Info**

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# - head will give top5 by default
# - tail will give bottom 5 data values by default

# %% [markdown]
# # how to access the middle or specific data among the dataframes
# - take \
# - iloc \
# - loc \

# %% [markdown]
# **CASE-1: i want to select 100,200,300 rows**
# **first i need to create a list of numbers[100,200,300]**
# **axis=0 so that it will indicate rows**

# %%
rows=[100,20,708]
visa_df.take(rows,axis=0)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 20    EZYV21      Asia              Master's                  N
# 708  EZYV709   Oceania            Bachelor's                  N
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 20                      N              880         2008                 West
# 708                     N             3227         1928              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 20          71128.98         Year                  Y      Denied
# 708         92422.74         Year                  Y   Certified

# %% [markdown]
# **because axis=1 means columns**

# %%
rows=[100,200,300]
visa_df.take(rows,axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 rows=[100,200,300]
# ----> 2 visa_df.take(rows,axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:891, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %% [markdown]
# - what is the draw back
# - we can extract specific rows from specific columns using single take
# - for example 100,200,300 rows from 5 8 10 columns using single take

# %%
rows=[100,200,300]
columns=[5,8,10]
visa_df.take(rows,axis=0).take(columns,axis=1)
# Out:
#      no_of_employees  prevailing_wage full_time_position
# 100             2227         28243.79                  Y
# 200             3282         74441.11                  Y
# 300             3268        101371.21                  Y

# %% [markdown]
# **iloc**

# %% [markdown]
# - DataFrame.iloc[rows,columns]
# - DataFrame.iloc[start:stop:step,start:stop:step]
# - DataFrame

# %%
rows=[100,105,1]
cols=[5,10,1]
visa_df.iloc[rows,cols]
# Out:
#      no_of_employees full_time_position      continent
# 100             2227                  Y           Asia
# 105             2317                  Y  North America
# 1               2412                  Y           Asia

# %%
visa_df.iloc[100:105:1,2:7:1]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 101              334         2007
# 102              224         2008
# 103              367         1982
# 104              306         2003

# %%
visa_df.iloc[[100,200,300],[5,8,10]]
visa_df.iloc[[100,200,300],5]
visa_df.iloc[[100,200,300],[5]]
visa_df.iloc[:,[5,8,10]]
visa_df.iloc[[100,200,300],:]
visa_df.iloc[100:106,[5,8,10]]
visa_df.iloc[[100,200,300],5:10]
visa_df.iloc[[100,200,300]]

# %%
visa_df.iloc[[100,200,300],[5,8,10]]
# Out:
#      no_of_employees  prevailing_wage full_time_position
# 100             2227         28243.79                  Y
# 200             3282         74441.11                  Y
# 300             3268        101371.21                  Y

# %%
visa_df.iloc[[100,200,300],5]
# Out:
# 100    2227
# 200    3282
# 300    3268
# Name: no_of_employees, dtype: int64

# %%
visa_df.iloc[[100,200,300],[5]]
# Out:
#      no_of_employees
# 100             2227
# 200             3282
# 300             3268

# %%
visa_df.iloc[100:106,[5,8,10]]
# Out:
#      no_of_employees  prevailing_wage full_time_position
# 100             2227         28243.79                  Y
# 101              334         43421.88                  Y
# 102              224         80253.78                  Y
# 103              367        115235.95                  Y
# 104              306         95200.86                  N
# 105             2317         41613.52                  Y

# %%
visa_df.iloc[[100,200,300],5:10]
# Out:
#      no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 100             2227         2007            Northeast         28243.79
# 200             3282         1979                 West         74441.11
# 300             3268         2012              Midwest        101371.21
#
#     unit_of_wage
# 100         Year
# 200         Year
# 300         Year

# %%
visa_df.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %% [markdown]
# # using loc we can provide direct names
# # using iloc we can't provide direct names,we should provide indices

# %% [markdown]
# **How to selct the columns**

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['continent']#series method
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df[['continent']]#DataFrame ,we can call it as generic expression
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %% [markdown]
# # direct accessing single column is called as series

# %%
visa_df.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df.loc[:,['continent']]
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
visa_df.loc[:,'continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object
